# %%
from cmlreaders import get_data_index, CMLReader
from matplotlib import pyplot as plt
import Reader
import ComputePower
import xarray as xr
import pandas as pd

# %%
df = get_data_index('r1')
df = df[df['experiment']=='TH1'][['subject', 'montage', 'localization', 'experiment']]

# %%
subject = df.iloc[0]

# %%
events = Reader.get_all_events(**subject)

# %%
pow_kwargs = {'transform': 'wavelet'}

# %%
basepow = ComputePower.get_basepow(events, [1,3], [1,2,3,4], 3000, subject, pow_kwargs=pow_kwargs)

# %%
basepow[0]
# Out:
# <xarray.DataArray (session: 2, channel: 4)>
# array([[7.7256668 , 7.81992154, 7.75980212, 7.77804046],
#        [7.63776707, 7.71827939, 7.78511142, 7.74493805]])
# Coordinates:
#     zstat    <U3 'mu'
#   * session  (session) int64 0 1
#   * channel  (channel) <U6 'LFPG2' 'LFPG3' 'LFPG4' 'LFPG5'

# %%
rel_start_ms
# Out:
# -7832

# %%
rel_stop_ms
# Out:
# -2467

# %%
freq_band=[1,3]
which_contacts=[1,]
buf_ms=3000
subject_dict=subject
eeg_kwargs={}
pow_kwargs={'transform': 'wavelet'}
wave_kwargs={}

besepow_mu = []
basepow_std = []

sessions = events['session'].drop_duplicates()
for i, (s, session) in enumerate(sessions.iteritems()):

    sess_mu = []
    sess_std = []

    sess_trials = events[
        events['session']==session]['trial'].drop_duplicates()
    for e, trial in sess_trials.iteritems():
        # ^ this will give e as the index of the first event from each trial
        event = events.loc[e]

        # determine baseline starts and stops
        rel_start_ms = event['baseline_start'] - event['mstime']
        rel_stop_ms = event['baseline_end'] - event['mstime']

        # load baseline eeg and power
        pre_trial_eeg = Reader.load_eeg(
            events.loc[e:e], which_contacts=which_contacts,
            rel_start_ms=rel_start_ms, rel_stop_ms=rel_stop_ms,
            buf_ms=buf_ms, do_average_ref=False,
            **subject_dict, **eeg_kwargs,
        )
        pre_trial_power = ComputePower.compute_power(
            pre_trial_eeg, freq_band, buf_ms=buf_ms,
            **pow_kwargs, **wave_kwargs
        )
        print(pre_trial_power.mean(dim=['event', 'time']).values)

        # get mean and std for each channel
        sess_mu.append(pre_trial_power.mean(dim=['event', 'time']))
        sess_std.append(pre_trial_power.std(dim=['event', 'time']))

    # add session averages accross trials to mu and std lists
    besepow_mu.append(xr.DataArray(sess_mu, coords=[sess_trials.values, pre_trial_power.channel],
                           dims=['trial', 'channel']).mean(dim='trial'))
    basepow_std.append(xr.DataArray(sess_std, coords=[sess_trials.values, pre_trial_power.channel],
                           dims=['trial', 'channel']).mean(dim='trial'))

# convert to xarrays
basepow = xr.DataArray([besepow_mu, basepow_std],
                       coords=[['mu', 'std'], sessions, pre_trial_power.channel],
                       dims=['zstat', 'session', 'channel'])
# Out:
# [7.60382408]
# [7.48171176]
# [8.27699037]
# [7.74578197]
# [7.76915771]
# [7.97359532]
# [7.82975711]
# [7.70702289]
# [7.66529694]
# [7.53721596]
# [7.67961208]
# [7.92269154]
# [7.91824872]
# [8.03110519]
# [7.72030221]
# [7.65588938]
# [7.3111296]
# [7.3134687]
# [7.54198856]
# [7.89551309]
# [7.78596887]
# [7.66890811]
# [7.7489709]
# [7.91763646]
# [7.75720503]
# [7.76008411]
# [7.76965829]
# [7.75700965]
# [7.82834881]
# [7.92427748]
# [8.08134298]
# [7.72936818]
# [7.56740803]
# [7.50082445]
# [7.54969678]
# [7.54514225]
# [7.9642147]
# [7.77243198]
# [7.35603728]
# [7.4618343]
# [7.92821674]
# [7.15162361]
# [7.53227644]
# [7.70560732]
# [7.19420244]
# [7.1218635]
# [7.23916788]
# [7.57802264]
# [7.69897855]
# [7.89425594]
# [7.83516968]
# [7.86934619]
# [7.53187444]
# [7.57593395]
# [7.50631273]
# [7.70750325]
# [7.94712335]
# [7.82833288]
# [7.78738624]
# [7.74902074]
# [7.80983641]
# [7.92727947]
# [7.60225104]
# [7.23702777]
# [7.4646746]
# [7.51550374]
# [7.5009269]
# [7.58797974]
# [7.70472031]
# [7.89808329]
# [7.89304172]
# [7.91187037]
# [7.44292012]
# [7.33433148]
# [7.77365439]
# [7.84737483]
# [7.59059474]
# [7.40540557]
# [7.86443609]
# [7.81655175]

# %%
basepow
# Out:
# <xarray.DataArray (zstat: 2, session: 2, channel: 1)>
# array([[[7.7256668 ],
#         [7.63776707]],
#
#        [[0.20690275],
#         [0.26255979]]])
# Coordinates:
#   * zstat    (zstat) <U3 'mu' 'std'
#   * session  (session) int64 0 1
#   * channel  (channel) <U6 'LFPG2'

# %%
basepow
# Out:
# <xarray.DataArray (zstat: 2, session: 2, channel: 1)>
# array([[[7.59217489],
#         [7.51283764]],
#
#        [[0.17861594],
#         [0.25978605]]])
# Coordinates:
#   * zstat    (zstat) <U3 'mu' 'std'
#   * session  (session) int64 0 1
#   * channel  (channel) <U6 'LFPG2'
